# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd #here I uploaded all the notebooks I need
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import requests

# %%
df=pd.read_csv("twitter-archive-enhanced.csv") #using pd.read() to resd the first dataset (csv)
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas   NaN     NaN    NaN   NaN
# 1                  10     Tilly   NaN     NaN    NaN   NaN
# 2                  10    Archie   NaN     NaN    NaN   NaN
# 3                  10     Darla   NaN     NaN    NaN   NaN
# 4                  10  Franklin   NaN     NaN    NaN   NaN

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
url ="https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url) #Using requests to get the dataset from the URL in the Udacity classroom
filename= "image_predections.tsv"
with open(filename, "wb") as file:
    file.write(response.content)

# %%
df2=pd.read_csv("image_predections.tsv", sep="\t") #reading the file after using the same function, ut since its a tsv file, I need to mention the separator
df2.head() #Using pd.head() to see i it was done right, and it was!
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
df3 = pd.read_json('tweet-json.txt', lines=True) #After getting the API seperately, I have the dowloaded JSON.txt file
#I read it using pd.read_json()

df3.to_csv('tweet-json.csv', index=False)

df3.head()
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...
# 1  {'media': [{'id': 892177413194625024, 'id_str'...
# 2  {'media': [{'id': 891815175371796480, 'id_str'...
# 3  {'media': [{'id': 891689552724799489, 'id_str'...
# 4  {'media': [{'id': 891327551943041024, 'id_str'...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ...  favorite_count  favorited  retweeted possibly_sensitive  \
# 0  ...           39467      False      False                0.0
# 1  ...           33819      False      False                0.0
# 2  ...           25461      False      False                0.0
# 3  ...           42908      False      False                0.0
# 4  ...           41048      False      False                0.0
#
#   possibly_sensitive_appealable  lang  retweeted_status quoted_status_id  \
# 0                           0.0    en               NaN              NaN
# 1                           0.0    en               NaN              NaN
# 2                           0.0    en               NaN              NaN
# 3                           0.0    en               NaN              NaN
# 4                           0.0    en               NaN              NaN
#
#    quoted_status_id_str  quoted_status
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
#
# [5 rows x 31 columns]

# %%
df3.info() #here Im using the info function for light assessing, I see thise definitly needs cleaning
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     float64
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   float64
#  25  possibly_sensitive_appealable  2211 non-null   float64
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     float64
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(11)
# memory usage: 505.9+ KB

# %%
def remove_retweets(df):
    retweet_columns = ['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp']
    return df[df[retweet_columns].isnull().all(axis=1)]
     # Remove retweets by filtering out rows where retweet-related columns are not null

# %%
df['tweet_id'].nunique()
# Out:
# 2356

# %%
df = remove_retweets(df)

# %%
df['tweet_id'].nunique()
# Out:
# 2175

# %% [markdown]
# # Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %%
df.head() #Using head() to visually assess
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas   NaN     NaN    NaN   NaN
# 1                  10     Tilly   NaN     NaN    NaN   NaN
# 2                  10    Archie   NaN     NaN    NaN   NaN
# 3                  10     Darla   NaN     NaN    NaN   NaN
# 4                  10  Franklin   NaN     NaN    NaN   NaN

# %%
df.tail(5) #Tail is the opposite of head and veiws the last few rows, also for visual assessment
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator name doggo floofer pupper puppo
# 2351                  10  NaN   NaN     NaN    NaN   NaN
# 2352                  10    a   NaN     NaN    NaN   NaN
# 2353                  10    a   NaN     NaN    NaN   NaN
# 2354                  10    a   NaN     NaN    NaN   NaN
# 2355                  10  NaN   NaN     NaN    NaN   NaN

# %%
df.info() #using info() again
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   object
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        1495 non-null   object
#  13  doggo                       87 non-null     object
#  14  floofer                     10 non-null     object
#  15  pupper                      234 non-null    object
#  16  puppo                       25 non-null     object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 370.4+ KB

# %%
df.nunique() #Seeing all the unique values
# Out:
# tweet_id                      2175
# in_reply_to_status_id           77
# in_reply_to_user_id             31
# timestamp                     2175
# source                           4
# text                          2175
# retweeted_status_id              0
# retweeted_status_user_id         0
# retweeted_status_timestamp       0
# expanded_urls                 2116
# rating_numerator                40
# rating_denominator              18
# name                           955
# doggo                            1
# floofer                          1
# pupper                           1
# puppo                            1
# dtype: int64

# %%
df.duplicated().sum() #seeing the duplicated
# Out:
# np.int64(0)

# %%
df2.head()#Using head() to visually assess
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
df2.tail() #Using taill to assess
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# 2070    True  German_short-haired_pointer  0.175219    True
# 2071    True                      spatula  0.040836   False
# 2072    True                       kelpie  0.031379    True
# 2073    True                     papillon  0.068957    True
# 2074   False                       banana  0.076110   False

# %%
df2.info() #Using info()to assess
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df2.describe() #Describe gives me a veiw of if I have outliers
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df2.nunique() #Seeing all unique values
# Out:
# tweet_id    2075
# jpg_url     2009
# img_num        4
# p1           378
# p1_conf     2006
# p1_dog         2
# p2           405
# p2_conf     2004
# p2_dog         2
# p3           408
# p3_conf     2006
# p3_dog         2
# dtype: int64

# %%
df2.duplicated().sum() #Seeing if there are duplicates
# Out:
# np.int64(0)

# %%
df3.head() #Assessing using head
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...
# 1  {'media': [{'id': 892177413194625024, 'id_str'...
# 2  {'media': [{'id': 891815175371796480, 'id_str'...
# 3  {'media': [{'id': 891689552724799489, 'id_str'...
# 4  {'media': [{'id': 891327551943041024, 'id_str'...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ...  favorite_count  favorited  retweeted possibly_sensitive  \
# 0  ...           39467      False      False                0.0
# 1  ...           33819      False      False                0.0
# 2  ...           25461      False      False                0.0
# 3  ...           42908      False      False                0.0
# 4  ...           41048      False      False                0.0
#
#   possibly_sensitive_appealable  lang  retweeted_status quoted_status_id  \
# 0                           0.0    en               NaN              NaN
# 1                           0.0    en               NaN              NaN
# 2                           0.0    en               NaN              NaN
# 3                           0.0    en               NaN              NaN
# 4                           0.0    en               NaN              NaN
#
#    quoted_status_id_str  quoted_status
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
#
# [5 rows x 31 columns]

# %%
df3["lang"].unique() #seeing al unique values in lang since I thought all of them were english
# Out:
# array(['en', 'und', 'in', 'eu', 'es', 'nl', 'tl', 'ro', 'et'],
#       dtype=object)

# %%
df3.info() #Usinf info() to assess
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   datetime64[ns, UTC]
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   int64
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     float64
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   float64
#  25  possibly_sensitive_appealable  2211 non-null   float64
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     float64
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(11)
# memory usage: 505.9+ KB

# %% [markdown]
# ### Quality issues
#
# 1.Inconsistent or invalid dog names in the name column
#
# 2.Timestamp in the first dataset is object when it should be datetime
#
# 3.tweet_id should be object
#
# 4.inconsistent capitalization in predictions
#
# 5.rating neumerator is bigger than denomenator
#
# 6.there should be only one trusted predection
#
# 7.missing data and ununified way of reffering to it
#
# 8.some values in lang coulmn are out dated

# %% [markdown]
# ### Tidiness issues
# 1.dog stages should be in one coulmn
#
# 2.all datasets should be merged

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
dfn= df.copy() #making copies so the original data isnt affected
df2n=df2.copy()
df3n=df3.copy()

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define: Some Names like "Such", are invalid dog names, and so we need to remove them and replace them with unknown

# %% [markdown]
# #### Code

# %%
dfn['name'] = dfn['name'].replace(['None', None], np.nan)

invalid_names = ['A', 'An', 'The', 'This', 'Such', 'Quite', 'Very', 'Actually',
                 'Just', 'Getting', 'One', 'My', 'O', 'Y', 'By', 'All']
dfn.loc[dfn['name'].isin(invalid_names), 'name'] = np.nan

too_short = dfn['name'].str.len() < 2
too_long = dfn['name'].str.len() > 15
dfn.loc[too_short | too_long, 'name'] = np.nan

dfn['name'] = dfn['name'].fillna('Unknown')
#this gets all the invalid names and replaces them with nan, then turns them to unknown so we dont have empty data

# %% [markdown]
# #### Test

# %%
dfn.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2097
# in_reply_to_user_id           2097
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   58
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                         2088
# floofer                       2165
# pupper                        1941
# puppo                         2150
# dtype: int64

# %%
dfn.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1616  685198997565345792                    NaN                  NaN
# 216   850753642995093505                    NaN                  NaN
# 1660  683078886620553216                    NaN                  NaN
# 1512  691321916024623104                    NaN                  NaN
# 2071  671115716440031232                    NaN                  NaN
#
#                       timestamp  \
# 1616  2016-01-07 20:39:06 +0000
# 216   2017-04-08 16:54:09 +0000
# 1660  2016-01-02 00:14:32 +0000
# 1512  2016-01-24 18:09:23 +0000
# 2071  2015-11-29 23:57:10 +0000
#
#                                                  source  \
# 1616  <a href="http://twitter.com/download/iphone" r...
# 216   <a href="http://twitter.com/download/iphone" r...
# 1660  <a href="http://twitter.com/download/iphone" r...
# 1512  <a href="http://twitter.com/download/iphone" r...
# 2071  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1616  This is Alfie. That is his time machine. He's ...                  NaN
# 216   This is Kyle. He made a joke about your shoes,...                  NaN
# 1660  Here we see a nifty leaping pupper. Feet look ...                  NaN
# 1512  This is Molly. She's a Peruvian Niddlewog. Lov...                  NaN
# 2071  Meet Phred. He isn't steering, looking at the ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1616                       NaN                        NaN
# 216                        NaN                        NaN
# 1660                       NaN                        NaN
# 1512                       NaN                        NaN
# 2071                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1616  https://twitter.com/dog_rates/status/685198997...                11
# 216   https://twitter.com/dog_rates/status/850753642...                11
# 1660  https://twitter.com/dog_rates/status/683078886...                 9
# 1512  https://twitter.com/dog_rates/status/691321916...                11
# 2071  https://twitter.com/dog_rates/status/671115716...                 6
#
#       rating_denominator     name doggo floofer  pupper puppo
# 1616                  10    Alfie   NaN     NaN     NaN   NaN
# 216                   10     Kyle   NaN     NaN     NaN   NaN
# 1660                  10  Unknown   NaN     NaN  pupper   NaN
# 1512                  10    Molly   NaN     NaN     NaN   NaN
# 2071                  10    Phred   NaN     NaN     NaN   NaN

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define Any time or date should be in the fore DateTime64[ns]

# %% [markdown]
# #### Code

# %%
dfn['timestamp'] = pd.to_datetime(dfn['timestamp']) #Converting using to_datetime()

# %% [markdown]
# #### Test

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   datetime64[ns, UTC]
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2175 non-null   object
#  13  doggo                       87 non-null     object
#  14  floofer                     10 non-null     object
#  15  pupper                      234 non-null    object
#  16  puppo                       25 non-null     object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(3), object(9)
# memory usage: 370.4+ KB

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define: Ids are not used for  mathematical operations and therefore are best converted into object data types

# %% [markdown]
# #### Code

# %%
dfn['tweet_id'] = dfn['tweet_id'].astype(object) #Using astype() tp cpnvert
df2n['tweet_id'] = dfn['tweet_id'].astype(object)

# %% [markdown]
# #### Test

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   object
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   datetime64[ns, UTC]
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2175 non-null   object
#  13  doggo                       87 non-null     object
#  14  floofer                     10 non-null     object
#  15  pupper                      234 non-null    object
#  16  puppo                       25 non-null     object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2), object(10)
# memory usage: 370.4+ KB

# %%
df2n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  1896 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Issue #4:

# %% [markdown]
# #### Define:The inconsistant capilatization is not efficient, and so we will convert everything into lowercase

# %% [markdown]
# #### Code

# %%
df2n['p1'] = df2n['p1'].str.lower()
df2n['p2'] = df2n['p2'].str.lower() #Using lower()
df2n['p3'] = df2n['p3'].str.lower()

# %% [markdown]
# #### Test

# %%
df2n.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 205   852912242202992640  https://pbs.twimg.com/media/CUwLtPeU8AAfAb2.jpg
# 1867  675334060156301312  https://pbs.twimg.com/media/C7X7Ui0XgAA3m19.jpg
# 1635  684222868335505415  https://pbs.twimg.com/media/CzBD7MWVIAA5ptx.jpg
# 812   771136648247640064  https://pbs.twimg.com/media/CZxc3G7WEAAM4Mv.jpg
# 1536  689905486972461056  https://pbs.twimg.com/media/Cvi2FiKWgAAif1u.jpg
#
#       img_num                  p1   p1_conf  p1_dog                p2  \
# 205         1          car_mirror  0.343063   False         seat_belt
# 1867        1  labrador_retriever  0.922540    True  golden_retriever
# 1635        1                chow  0.835102    True        pomeranian
# 812         1      siberian_husky  0.486428    True        eskimo_dog
# 1536        2        refrigerator  0.998886   False          malinois
#
#        p2_conf  p2_dog              p3   p3_conf  p3_dog
# 205   0.110289   False            wing  0.080148   False
# 1867  0.074358    True  great_pyrenees  0.002325    True
# 1635  0.040783    True      eskimo_dog  0.021274    True
# 812   0.448518    True      white_wolf  0.041506   False
# 1536  0.000153    True          kelpie  0.000131    True

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# #### Define: The denomenator should be more not less than neumerator

# %% [markdown]
# #### Code

# %%
dfn['rating'] = ((dfn['rating_numerator'] / dfn['rating_denominator']) * 100).clip(upper=100)
dfn['rating'] = dfn['rating'].round(0).astype(int).astype(str) + '%' #this makes sure that it doesnt go over 100%

dfn.drop(['rating_numerator', 'rating_denominator'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
dfn.sample(6)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1729  679862121895714818                    NaN                  NaN
# 1899  674670581682434048                    NaN                  NaN
# 1447  696488710901260288                    NaN                  NaN
# 1481  693280720173801472                    NaN                  NaN
# 494   813187593374461952                    NaN                  NaN
# 365   829011960981237760                    NaN                  NaN
#
#                      timestamp  \
# 1729 2015-12-24 03:12:15+00:00
# 1899 2015-12-09 19:22:56+00:00
# 1447 2016-02-08 00:20:23+00:00
# 1481 2016-01-30 03:52:58+00:00
# 494  2016-12-26 01:00:05+00:00
# 365  2017-02-07 17:00:28+00:00
#
#                                                  source  \
# 1729  <a href="http://twitter.com/download/iphone" r...
# 1899  <a href="http://twitter.com/download/iphone" r...
# 1447  <a href="http://twitter.com/download/iphone" r...
# 1481  <a href="http://twitter.com/download/iphone" r...
# 494   <a href="http://twitter.com/download/iphone" r...
# 365   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1729  "Dammit hooman I'm jus trynna lik the fler" 11...                  NaN
# 1899  Meet Jeb &amp; Bush. Jeb is somehow stuck in t...                  NaN
# 1447     12/10 revolutionary af https://t.co/zKzq4nIY86                  NaN
# 1481  This is Sadie and her 2 pups Shebang &amp; Ruf...                  NaN
# 494   We only rate dogs. Please don't send in other ...                  NaN
# 365   This is Dexter. He was reunited with his mom y...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1729                       NaN                        NaN
# 1899                       NaN                        NaN
# 1447                       NaN                        NaN
# 1481                       NaN                        NaN
# 494                        NaN                        NaN
# 365                        NaN                        NaN
#
#                                           expanded_urls     name doggo  \
# 1729  https://twitter.com/dog_rates/status/679862121...  Unknown   NaN
# 1899  https://twitter.com/dog_rates/status/674670581...      Jeb   NaN
# 1447  https://twitter.com/dog_rates/status/696488710...  Unknown   NaN
# 1481  https://twitter.com/dog_rates/status/693280720...    Sadie   NaN
# 494   https://twitter.com/dog_rates/status/813187593...  Unknown   NaN
# 365   https://twitter.com/dog_rates/status/829011960...   Dexter   NaN
#
#      floofer pupper puppo rating
# 1729     NaN    NaN   NaN   100%
# 1899     NaN    NaN   NaN    90%
# 1447     NaN    NaN   NaN   100%
# 1481     NaN    NaN   NaN   100%
# 494      NaN    NaN   NaN   100%
# 365      NaN    NaN   NaN   100%

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Define:There should be only ONE trusted dog predection

# %% [markdown]
# #### Code

# %%
# Step 1: Identify confidence and label columns
conf_cols = ['p1_conf', 'p2_conf', 'p3_conf']
label_cols = ['p1', 'p2', 'p3']

# Step 2: Assign the index of the highest confidence prediction
max_conf_idx = df2n[conf_cols].values.argmax(axis=1)

# Step 3: Use that index to get the initial best_prediction
df2n['best_prediction'] = [row[i] for row, i in zip(df2n[label_cols].values, max_conf_idx)]

# Step 4: Get all known dog breeds based on 'p1_dog', 'p2_dog', 'p3_dog'
dog_breeds = pd.concat([
    df2n[df2n['p1_dog']]['p1'],
    df2n[df2n['p2_dog']]['p2'],
    df2n[df2n['p3_dog']]['p3']
]).unique()
dog_breeds = set(dog_breeds)

# Step 5: Replace non-dog predictions with next best option if available
mask1 = ~df2n['best_prediction'].isin(dog_breeds) & df2n['p2'].isin(dog_breeds)
mask2 = ~df2n['best_prediction'].isin(dog_breeds) & ~df2n['p2'].isin(dog_breeds) & df2n['p3'].isin(dog_breeds)

df2n.loc[mask1, 'best_prediction'] = df2n.loc[mask1, 'p2']
df2n.loc[mask2, 'best_prediction'] = df2n.loc[mask2, 'p3']

# Step 6: Keep only rows where the best_prediction is a valid dog
df2n = df2n[df2n['best_prediction'].isin(dog_breeds)]

# %%
df2n.drop(['p1', 'p1_conf', 'p1_dog',
                'p2', 'p2_conf', 'p2_dog',
                'p3', 'p3_conf', 'p3_dog'], axis=1, inplace=True, errors="ignore")
# Out:
# <ipython-input-197-4ae18cfb058c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2n.drop(['p1', 'p1_conf', 'p1_dog',

# %% [markdown]
# #### Test

# %%
df2n.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  892420643555336193  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  892177421306343426  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  891815181378084864  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  891689557279858688  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  891327558926688256  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num         best_prediction
# 0        1  welsh_springer_spaniel
# 1        1                 redbone
# 2        1         german_shepherd
# 3        1     rhodesian_ridgeback
# 4        1      miniature_pinscher

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Define: There are missing data reffered to in a different way, We should unify the Missing data to be reffered to as "Unknown"

# %% [markdown]
# #### Code

# %%
df3n['lang'].replace('und', np.nan, inplace=True)
df3n['lang'].fillna(df3n['lang'].mode()[0], inplace=True) #filling with mode
# Out:
# <ipython-input-199-2646bc467dd4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3n['lang'].replace('und', np.nan, inplace=True)
# <ipython-input-199-2646bc467dd4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3n['lang'].fillna(df3n['lang'].mode()[0], inplace=True) #filling with mode

# %%
dfn[['doggo', 'floofer', 'pupper', 'puppo']] = dfn[['doggo', 'floofer', 'pupper', 'puppo']].replace('None', np.nan).fillna("Unknown") #making them to unknown

# %% [markdown]
# #### Test

# %%
(dfn[['doggo', 'floofer', 'pupper', 'puppo']] == 'None').sum()
# Out:
# doggo      0
# floofer    0
# pupper     0
# puppo      0
# dtype: int64

# %%
dfn[['doggo', 'floofer', 'pupper', 'puppo']].isna().sum()
# Out:
# doggo      0
# floofer    0
# pupper     0
# puppo      0
# dtype: int64

# %%
dfn.sample()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1508  691483041324204033                    NaN                  NaN
#
#                      timestamp  \
# 1508 2016-01-25 04:49:38+00:00
#
#                                                  source  \
# 1508  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1508  When bae says they can't go out but you see th...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1508                       NaN                        NaN
#
#                                           expanded_urls     name    doggo  \
# 1508  https://twitter.com/dog_rates/status/691483041...  Unknown  Unknown
#
#       floofer   pupper    puppo rating
# 1508  Unknown  Unknown  Unknown    50%

# %% [markdown]
# ### Issue #8:

# %% [markdown]
# #### Define: The indonesian language should be reffered to as Id instead of In for this ted had become outdated

# %% [markdown]
# #### Code

# %%
df3n['lang'] = df3n['lang'].replace({'in': 'id'}) #changing every in to id

# %% [markdown]
# #### Test

# %%
print(df3n['lang'].unique())
# Out:
# ['en' 'id' 'eu' 'es' 'nl' 'tl' 'ro' 'et']

# %% [markdown]
# ### Issue #9:

# %% [markdown]
# #### Define:All dog stages shoud be combined into one coulmn

# %% [markdown]
# #### Code

# %%
def combine_stages(row):
    stages = []
    for stage in ['doggo', 'floofer', 'pupper', 'puppo']:
        if pd.notna(row[stage]) and row[stage] != 'Unknown': #I used a funtion fot that
            stages.append(row[stage])
    return ', '.join(stages) if stages else 'Unknown'

dfn['dog_stage'] = dfn.apply(combine_stages, axis=1)

# %%
dfn.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls      name    doggo  \
# 0  https://twitter.com/dog_rates/status/892420643...   Phineas  Unknown
# 1  https://twitter.com/dog_rates/status/892177421...     Tilly  Unknown
# 2  https://twitter.com/dog_rates/status/891815181...    Archie  Unknown
# 3  https://twitter.com/dog_rates/status/891689557...     Darla  Unknown
# 4  https://twitter.com/dog_rates/status/891327558...  Franklin  Unknown
#
#    floofer   pupper    puppo rating dog_stage
# 0  Unknown  Unknown  Unknown   100%   Unknown
# 1  Unknown  Unknown  Unknown   100%   Unknown
# 2  Unknown  Unknown  Unknown   100%   Unknown
# 3  Unknown  Unknown  Unknown   100%   Unknown
# 4  Unknown  Unknown  Unknown   100%   Unknown

# %%
dfn.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1, inplace=True)

# %%
dfn.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 917   756939218950160384                    NaN                  NaN
# 2138  670040295598354432                    NaN                  NaN
# 262   842765311967449089                    NaN                  NaN
# 1224  714214115368108032                    NaN                  NaN
# 1692  681302363064414209                    NaN                  NaN
#
#                      timestamp  \
# 917  2016-07-23 19:49:07+00:00
# 2138 2015-11-27 00:43:49+00:00
# 262  2017-03-17 15:51:22+00:00
# 1224 2016-03-27 22:14:49+00:00
# 1692 2015-12-28 02:35:15+00:00
#
#                                                  source  \
# 917   <a href="http://twitter.com/download/iphone" r...
# 2138  <a href="http://twitter.com/download/iphone" r...
# 262   <a href="http://twitter.com/download/iphone" r...
# 1224  <a href="http://twitter.com/download/iphone" r...
# 1692  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 917   This is Jax. He is a majestic mountain pupper....                  NaN
# 2138  😂😂😂 10/10 for the dog and the owner https://t....                  NaN
# 262   Meet Indie. She's not a fan of baths but she's...                  NaN
# 1224  Happy Easter from the squad! 🐇🐶 13/10 for all ...                  NaN
# 1692  This is Chuck. He's a neat dog. Very flexible....                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 917                        NaN                        NaN
# 2138                       NaN                        NaN
# 262                        NaN                        NaN
# 1224                       NaN                        NaN
# 1692                       NaN                        NaN
#
#                                           expanded_urls     name rating  \
# 917   https://twitter.com/dog_rates/status/756939218...      Jax   100%
# 2138  https://twitter.com/dog_rates/status/670040295...  Unknown   100%
# 262   https://www.gofundme.com/get-indie-home/,https...    Indie   100%
# 1224  https://twitter.com/dog_rates/status/714214115...  Unknown   100%
# 1692  https://twitter.com/dog_rates/status/681302363...    Chuck    30%
#
#      dog_stage
# 917     pupper
# 2138   Unknown
# 262    Unknown
# 1224   Unknown
# 1692   Unknown

# %% [markdown]
# ### Issue #10:

# %% [markdown]
# #### Define: All Datasets Should Be Merged

# %% [markdown]
# #### Code

# %%
# First merge df and df2 on 'tweet_id'
df_merged = pd.merge(dfn, df2n, on='tweet_id', how='left') #merging on two keys since I didnt find a common one

# Then merge the result with df3 on 'tweet_id'
twitter_archive_master = pd.merge(df_merged, df3n, on='source', how='right')

# %% [markdown]
# #### Test

# %%
twitter_archive_master.head()
# Out:
#              tweet_id  in_reply_to_status_id_x  in_reply_to_user_id_x  \
# 0  892420643555336193                      NaN                    NaN
# 1  892177421306343426                      NaN                    NaN
# 2  891815181378084864                      NaN                    NaN
# 3  891689557279858688                      NaN                    NaN
# 4  891327558926688256                      NaN                    NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  ... favorite_count  \
# 0  https://twitter.com/dog_rates/status/892420643...  ...          39467
# 1  https://twitter.com/dog_rates/status/892177421...  ...          39467
# 2  https://twitter.com/dog_rates/status/891815181...  ...          39467
# 3  https://twitter.com/dog_rates/status/891689557...  ...          39467
# 4  https://twitter.com/dog_rates/status/891327558...  ...          39467
#
#   favorited retweeted possibly_sensitive  possibly_sensitive_appealable lang  \
# 0     False     False                0.0                            0.0   en
# 1     False     False                0.0                            0.0   en
# 2     False     False                0.0                            0.0   en
# 3     False     False                0.0                            0.0   en
# 4     False     False                0.0                            0.0   en
#
#   retweeted_status  quoted_status_id  quoted_status_id_str quoted_status
# 0              NaN               NaN                   NaN           NaN
# 1              NaN               NaN                   NaN           NaN
# 2              NaN               NaN                   NaN           NaN
# 3              NaN               NaN                   NaN           NaN
# 4              NaN               NaN                   NaN           NaN
#
# [5 rows x 46 columns]

# %%
twitter_archive_master.sample(5)
# Out:
#                    tweet_id  in_reply_to_status_id_x  in_reply_to_user_id_x  \
# 3627695  762699858130116608                      NaN                    NaN
# 223260   762316489655476224                      NaN                    NaN
# 1801385  742423170473463808                      NaN                    NaN
# 113916   674737130913071104                      NaN                    NaN
# 3654477  727314416056803329                      NaN                    NaN
#
#                         timestamp  \
# 3627695 2016-08-08 17:19:51+00:00
# 223260  2016-08-07 15:56:28+00:00
# 1801385 2016-06-13 18:27:32+00:00
# 113916  2015-12-09 23:47:22+00:00
# 3654477 2016-05-03 01:50:44+00:00
#
#                                                     source  \
# 3627695  <a href="http://twitter.com/download/iphone" r...
# 223260   <a href="http://twitter.com/download/iphone" r...
# 1801385  <a href="http://twitter.com/download/iphone" r...
# 113916   <a href="http://twitter.com/download/iphone" r...
# 3654477  <a href="http://twitter.com/download/iphone" r...
#
#                                                       text  \
# 3627695  This is Leela. She's a Fetty Woof. Lost eye wh...
# 223260   This is Scout. He specializes in mid-air freez...
# 1801385  This is Bell. She likes holding hands. 12/10 w...
# 113916   Meet Rufio. He is unaware of the pink legless ...
# 3654477  This pupper was about to explain where that di...
#
#          retweeted_status_id  retweeted_status_user_id  \
# 3627695                  NaN                       NaN
# 223260                   NaN                       NaN
# 1801385                  NaN                       NaN
# 113916                   NaN                       NaN
# 3654477                  NaN                       NaN
#
#         retweeted_status_timestamp  \
# 3627695                        NaN
# 223260                         NaN
# 1801385                        NaN
# 113916                         NaN
# 3654477                        NaN
#
#                                              expanded_urls  ...  \
# 3627695  https://twitter.com/dog_rates/status/762699858...  ...
# 223260   https://twitter.com/dog_rates/status/762316489...  ...
# 1801385  https://twitter.com/dog_rates/status/742423170...  ...
# 113916   https://twitter.com/dog_rates/status/674737130...  ...
# 3654477  https://twitter.com/dog_rates/status/727314416...  ...
#
#         favorite_count favorited retweeted possibly_sensitive  \
# 3627695           1180     False     False                0.0
# 223260           21461     False     False                0.0
# 1801385           3001     False     False                0.0
# 113916           50199     False     False                0.0
# 3654477           1751     False     False                0.0
#
#          possibly_sensitive_appealable lang retweeted_status  \
# 3627695                            0.0   nl              NaN
# 223260                             0.0   en              NaN
# 1801385                            0.0   en              NaN
# 113916                             0.0   en              NaN
# 3654477                            0.0   en              NaN
#
#          quoted_status_id  quoted_status_id_str  \
# 3627695               NaN                   NaN
# 223260       8.710758e+17          8.710758e+17
# 1801385               NaN                   NaN
# 113916                NaN                   NaN
# 3654477               NaN                   NaN
#
#                                              quoted_status
# 3627695                                                NaN
# 223260   {'created_at': 'Sat Jun 03 18:46:59 +0000 2017...
# 1801385                                                NaN
# 113916                                                 NaN
# 3654477                                                NaN
#
# [5 rows x 46 columns]

# %%
twitter_archive_master['source_clean'] = twitter_archive_master['source'].str.split('>').str[1].str.split('<').str[0]
twitter_archive_master.drop(["source"], axis=1, inplace=True, errors="ignore") # Additional cleaning to get only the device

# %%
twitter_archive_master.sample(5)
# Out:
#                    tweet_id  in_reply_to_status_id_x  in_reply_to_user_id_x  \
# 414155   673352124999274496                      NaN                    NaN
# 3723649  783391753726550016                      NaN                    NaN
# 1267956  675898130735476737                      NaN                    NaN
# 835558   842535590457499648                      NaN                    NaN
# 2486599  699779630832685056                      NaN                    NaN
#
#                         timestamp  \
# 414155  2015-12-06 04:03:51+00:00
# 3723649 2016-10-04 19:42:03+00:00
# 1267956 2015-12-13 04:40:46+00:00
# 835558  2017-03-17 00:38:32+00:00
# 2486599 2016-02-17 02:17:19+00:00
#
#                                                       text  \
# 414155   *lets out a tiny screech and then goes into co...
# 3723649  Meet Godi. He's an avid beachgoer and part tim...
# 1267956  I'm sure you've all seen this pupper. Not prep...
# 835558   This is Winnie. She lost her body saving a chi...
# 2486599   Take all my money. 10/10 https://t.co/B28ebc5LzQ
#
#          retweeted_status_id  retweeted_status_user_id  \
# 414155                   NaN                       NaN
# 3723649                  NaN                       NaN
# 1267956                  NaN                       NaN
# 835558                   NaN                       NaN
# 2486599                  NaN                       NaN
#
#         retweeted_status_timestamp  \
# 414155                         NaN
# 3723649                        NaN
# 1267956                        NaN
# 835558                         NaN
# 2486599                        NaN
#
#                                              expanded_urls     name  ...  \
# 414155   https://twitter.com/dog_rates/status/673352124...  Unknown  ...
# 3723649  https://twitter.com/dog_rates/status/783391753...     Godi  ...
# 1267956  https://twitter.com/dog_rates/status/675898130...  Unknown  ...
# 835558   https://twitter.com/dog_rates/status/842535590...   Winnie  ...
# 2486599  https://twitter.com/dog_rates/status/699779630...  Unknown  ...
#
#         favorited retweeted possibly_sensitive  possibly_sensitive_appealable  \
# 414155      False     False                0.0                            0.0
# 3723649     False     False                0.0                            0.0
# 1267956     False     False                0.0                            0.0
# 835558      False     False                0.0                            0.0
# 2486599     False     False                0.0                            0.0
#
#         lang                                   retweeted_status  \
# 414155    en                                                NaN
# 3723649   en                                                NaN
# 1267956   en  {'created_at': 'Wed Oct 19 15:37:03 +0000 2016...
# 835558    en  {'created_at': 'Fri Jan 20 17:00:46 +0000 2017...
# 2486599   en                                                NaN
#
#          quoted_status_id  quoted_status_id_str quoted_status  \
# 414155                NaN                   NaN           NaN
# 3723649               NaN                   NaN           NaN
# 1267956               NaN                   NaN           NaN
# 835558                NaN                   NaN           NaN
# 2486599               NaN                   NaN           NaN
#
#                source_clean
# 414155   Twitter for iPhone
# 3723649  Twitter for iPhone
# 1267956  Twitter for iPhone
# 835558   Twitter for iPhone
# 2486599  Twitter for iPhone
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
twitter_archive_master.to_csv('twitter_archive_master.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-215-ae2b622ff3e6> in <cell line: 0>()
# ----> 1 twitter_archive_master.to_csv('twitter_archive_master.csv', index=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in save(self)
#     268             )
#     269
# --> 270             self._save()
#     271
#     272     def _save(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#     276
#     277     def _save_header(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#     314
#     315     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324         libwriters.write_csv_rows(
#     325             data,
#     326             ix,
#
# writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
top_breeds= twitter_archive_master["best_prediction"].value_counts().nlargest(3) #getting top 3 breeds using value_counts()

# %%
best_langs= twitter_archive_master.groupby('lang')['favorite_count'].mean().nlargest(3) #getting top 3 langs using groupby

# %%
best_stage= twitter_archive_master["dog_stage"].value_counts().nlargest(3) #getting top three stages using value_counts()

# %%
most_source= twitter_archive_master.groupby('source_clean')['favorite_count'].mean().nlargest(3) #getting top three devices using groupby()

# %% [markdown]
# ### Insights:
# 1.The Golden Retriever received the highest average favorite count
#
# 2.Indonesian is the language with the most favorite count
#
# 3.Pupper is the most favorited stage on twitrter
#
# 4.Iphone is the most used source to favoriting tweets

# %% [markdown]
# ### Visualization

# %%
top_breeds.plot.pie(autopct='%1.1f%%', figsize=(8, 8), title='Top 3 Dog Breeds by Average Favorite Count')
plt.ylabel('')  #hides the y-axis
plt.show()

# %%
best_langs.plot(kind="bar", alpha=0.7, figsize=(8,5),title='Most Favorited Languages in twitter');
plt.ylabel("favorite count")
# Out:
# Text(0, 0.5, 'favorite count')

# %%
best_stage.plot(kind="barh", alpha=0.7, figsize=(8,5), title='Most Favorit');
plt.ylabel("favorite count")
# Out:
# Text(0, 0.5, 'favorite count')

# %%
most_source.plot(kind="barh", alpha=0.7, figsize=(8,5), title='Most Favorite Device');
plt.ylabel("favorite count")
# Out:
# Text(0, 0.5, 'favorite count')
